# %% [markdown]
# # STRAVA API AND CYCLING ACTIVITY SUMMARY DATA

# %% [markdown]
# ---
# ---
# # Imports

# %%
# https://towardsdatascience.com/using-the-strava-api-and-pandas-to-explore-your-activity-data-d94901d9bfde
# https://www.youtube.com/watch?v=sgscChKfGyg&t=258s
# https://github.com/franchyze923/Code_From_Tutorials/blob/master/Strava_Api/strava_api.py
# Lesson 5.01 APIs
# Lesson 8.02 Timeseries

# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import requests
import urllib3

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---
# # API

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

payload = {
    'client_id': "89682",
    'client_secret': '0211f1fcd1e21bf52f9690ed169fcbd4d886f602',
    'refresh_token': '7a3f31cb96a242deb9e08de21eee388496d44bd0',
    'grant_type': "refresh_token",
    'f': 'json'
}

print("Requesting Token...\n")
res = requests.post(auth_url, data=payload, verify=False)
access_token = res.json()['access_token']
print("Access Token = {}\n".format(access_token))

header = {'Authorization': 'Bearer ' + access_token}
param = {'per_page': 200, 'page': 1}
my_dataset = requests.get(activites_url, headers=header, params=param).json()

print(my_dataset[0]["name"])
print(my_dataset[0]["map"]["summary_polyline"])
# Out:
# Requesting Token...
#
# Access Token = 40e6173a01a0ea40259137b1847a680c7ce1ff2f
#
# Lunch Ride ☀️
# kfukFvzzcVIlCRr@R|AFlBt@bEhDzJGtDC\c@lASvC?xALr@aAnB}AnFc@f@{A~@o@z@KXChAIZgCpCgA`AWDuCw@yCa@UGU[qBE}@]mBoAuAz@qATy@Z_ABiA[aAReBM{EfAy@DgAYmEQqAq@YCoATi@O{@oAeB}A_DoFe@kAJ_Bu@yAe@mDf@cLDyIgEF{AC}AL_IQkDBGKDaIVo@AYQMmBD_Bm@a@AKMEk@t@iCh@s@dG{ClEuCzBiDnBqDd@qG~@mGxBoG@YKWk@e@_@y@KeHNmEf@cECwBn@_CLgId@cKzBcJ`EaHF}@w@gFKqB}@yGq@wDi@w@_DoA[k@qAoAc@gBk@kAqAmBy@s@oBqEIq@VcLUcDHmAUkB?oCE[_@i@cB[OS}AyF_CqLGcAuAo@RcBBiBc@}KiCmFY_CeB_FsA_CAq@VeB`A_B`@yDh@u@bAKl@s@TiCi@cDeAsAsAM}@a@wI]c@]W}@e@_EC_BPsAz@wAXsADqAGiEg@_AIa@r@cCBYKcD^oHImAy@_FOm@aA{Bo@{CMqGkAuB}BwDO_AH]nCuD\_AFk@?{DD]Ve@|@QOEa@Pc@d@Gb@?`EMx@g@jAyBrCM^A`@Lj@x@zA~AzBx@`BFxFx@pD~@~Bx@|ENbB]jJJ|Bi@jBQlAd@v@R`EAp@_@~Bg@r@Wt@KvAr@jGRp@n@`@bAC|FZ|@b@~AN`@\l@pA^jCSbCMXi@b@m@@YNu@rAOlCaAjBSpB@ZNd@x@hAj@vAlArDVpB`CxEh@vME`DHRl@PJfA|B`LxA`GNTjBX`@l@D\?`DTrAIfBRdCUhK?~@H\tBrEdA`A`A|AdBlEv@j@^p@xCfAd@h@Tx@j@`ErB~PM`AkChE}@jBeB|GQvAYhIQlIm@hCGd@@xAa@lEKnDJtHJXdA`AFb@yBlGy@hFQhBcAnd@DzGDZ`@|@NHlHIJHK`Je@~KFj@f@jCr@pA@XOn@Fd@rDnGn@v@bAt@x@pA~@PtAU`An@rFR|@Zt@GtEkAdBPhAU`A\dAEx@_@nAS|@q@VEfCbBxANx@Cj@b@nAHbFnA`@MzDsELcBv@mA|BcBbAuDn@eBl@cA@QMqAFcCL}Ad@uAFsDIe@oD{Jk@iD?iAWyBSu@?o@

# %%
# JSON
activities = json_normalize(my_dataset)

# %%
activities.head()
# Out:
#    resource_state                                               name  \
# 0               2                                      Lunch Ride ☀️
# 1               2  20 min EDM Full Body Strength with Daniel McKenna
# 2               2                                    Evening Ride ☀️
# 3               2                                    Morning Ride ☀️
# 4               2                          CycleBar - Afternoon Ride
#
#    distance  moving_time  elapsed_time  total_elevation_gain     type  \
# 0   27470.9         4602          5205                  73.0     Ride
# 1       0.0         1199          1199                   0.0  Workout
# 2   18334.6         3094          3210                  38.0     Ride
# 3   50871.7         9835         12885                 419.0     Ride
# 4       0.0         2923          2923                   0.0     Ride
#
#   sport_type  workout_type          id            start_date  \
# 0       Ride           NaN  7555695408  2022-07-30T19:29:34Z
# 1    Workout           NaN  7550519896  2022-07-29T22:30:41Z
# 2       Ride           NaN  7534784479  2022-07-27T01:00:54Z
# 3       Ride          10.0  7517199706  2022-07-23T16:12:21Z
# 4       Ride          10.0  7507557354  2022-07-21T23:27:51Z
#
#        start_date_local                         timezone  utc_offset  \
# 0  2022-07-30T12:29:34Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 1  2022-07-29T15:30:41Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 2  2022-07-26T18:00:54Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 3  2022-07-23T09:12:21Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 4  2022-07-21T16:27:51Z                  (GMT-07:00) MST    -25200.0
#
#   location_city location_state location_country  achievement_count  \
# 0          None           None    United States                  0
# 1          None           None    United States                  0
# 2          None           None    United States                  0
# 3          None           None    United States                 29
# 4          None           None    United States                  0
#
#    kudos_count  comment_count  athlete_count  photo_count  trainer  commute  \
# 0            0              0              1            0    False    False
# 1            1              0              1            0     True    False
# 2            1              0              1            0    False    False
# 3            1              0              1            0    False    False
# 4            1              0              1            0     True    False
#
#    manual  private visibility  flagged    gear_id  \
# 0   False    False   everyone    False  b10571102
# 1   False    False   everyone    False       None
# 2   False    False   everyone    False  b10571102
# 3   False    False   everyone    False  b10571102
# 4   False    False   everyone    False  b10571102
#
#                                 start_latlng  \
# 0   [38.77374228090048, -121.36347443796694]
# 1                                         []
# 2  [38.773648738861084, -121.36368323117495]
# 3  [38.633550172671676, -121.21844915673137]
# 4                                         []
#
#                                  end_latlng  average_speed  max_speed  \
# 0  [38.77376575022936, -121.36364182457328]          5.969      8.935
# 1                                        []          0.000      0.000
# 2  [38.77378385514021, -121.36365816928446]          5.926      8.766
# 3  [38.63322361372411, -121.21896212920547]          5.173     12.998
# 4                                        []          0.000      0.000
#
#    average_cadence  has_heartrate  average_heartrate  max_heartrate  \
# 0             65.6           True              133.4          157.0
# 1              NaN          False                NaN            NaN
# 2             64.1           True              131.4          155.0
# 3             62.5           True              139.9          169.0
# 4              NaN           True              153.8          178.0
#
#    heartrate_opt_out  display_hide_heartrate_option  elev_high  elev_low  \
# 0              False                           True       37.6      15.2
# 1              False                          False        NaN       NaN
# 2              False                           True       36.4      21.0
# 3              False                           True      149.0      35.4
# 4              False                           True        NaN       NaN
#
#     upload_id upload_id_str                           external_id  \
# 0  8057653527    8057653527                garmin_push_9305828885
# 1  8051901564    8051901564  30df8ed553b1444e9bc0b25090e29ef4.tcx
# 2  8034472252    8034472252                garmin_push_9281307583
# 3  8014855808    8014855808                garmin_push_9260725778
# 4  8004160446    8004160446                garmin_push_9249375319
#
#    from_accepted_tag  pr_count  total_photo_count  has_kudoed  suffer_score  \
# 0              False         0                  0       False          42.0
# 1              False         0                  1       False           NaN
# 2              False         0                  0       False          25.0
# 3              False        13                  1       False         146.0
# 4              False         0                  0       False          86.0
#
#    athlete.id  athlete.resource_state       map.id  \
# 0     7321904                       1  a7555695408
# 1     7321904                       1  a7550519896
# 2     7321904                       1  a7534784479
# 3     7321904                       1  a7517199706
# 4     7321904                       1  a7507557354
#
#                                 map.summary_polyline  map.resource_state  \
# 0  kfukFvzzcVIlCRr@R|AFlBt@bEhDzJGtDC\c@lASvC?xAL...                   2
# 1                                               None                   2
# 2  mfukFz{zcVGvAFd@Lf@X~BCj@@Xv@fEv@~Bf@hA~@jCJh@...                   2
# 3  urxjFhnzbVXWiAiG}D?Tc@fD`@^}Aw@}B}DkAS_IjBmCcF...                   2
# 4                                               None                   2
#
#    average_watts  max_watts  weighted_average_watts  kilojoules device_watts
# 0            NaN        NaN                     NaN         NaN          NaN
# 1            NaN        NaN                     NaN         NaN          NaN
# 2            NaN        NaN                     NaN         NaN          NaN
# 3            NaN        NaN                     NaN         NaN          NaN
# 4            NaN        NaN                     NaN         NaN          NaN

# %%
activities.columns
# Out:
# Index(['resource_state', 'name', 'distance', 'moving_time', 'elapsed_time',
#        'total_elevation_gain', 'type', 'sport_type', 'workout_type', 'id',
#        'start_date', 'start_date_local', 'timezone', 'utc_offset',
#        'location_city', 'location_state', 'location_country',
#        'achievement_count', 'kudos_count', 'comment_count', 'athlete_count',
#        'photo_count', 'trainer', 'commute', 'manual', 'private', 'visibility',
#        'flagged', 'gear_id', 'start_latlng', 'end_latlng', 'average_speed',
#        'max_speed', 'average_cadence', 'has_heartrate', 'average_heartrate',
#        'max_heartrate', 'heartrate_opt_out', 'display_hide_heartrate_option',
#        'elev_high', 'elev_low', 'upload_id', 'upload_id_str', 'external_id',
#        'from_accepted_tag', 'pr_count', 'total_photo_count', 'has_kudoed',
#        'suffer_score', 'athlete.id', 'athlete.resource_state', 'map.id',
#        'map.summary_polyline', 'map.resource_state', 'average_watts',
#        'max_watts', 'weighted_average_watts', 'kilojoules', 'device_watts'],
#       dtype='object')

# %%
#Break date into start time and date
activities['start_date_local'] = pd.to_datetime(activities['start_date_local'])
activities['start_time'] = activities['start_date_local'].dt.time
activities['start_date_local'] = activities['start_date_local'].dt.date

# %%
# clean up to wanted columns
cols = ['id', 'name', 'type', 'sport_type', 'start_date_local', 'start_time', 
        'start_latlng', 'end_latlng', 'distance', 'moving_time', 'elapsed_time', 
        'average_speed', 'max_speed', 'average_cadence', 'average_heartrate', 
        'max_heartrate', 'suffer_score', 'total_elevation_gain', 'elev_high', 
        'elev_low', 'map.id', 'map.summary_polyline', 'map.resource_state']
activities = activities[cols]

# %%
activities.head()
# Out:
#            id                                               name     type  \
# 0  7555695408                                      Lunch Ride ☀️     Ride
# 1  7550519896  20 min EDM Full Body Strength with Daniel McKenna  Workout
# 2  7534784479                                    Evening Ride ☀️     Ride
# 3  7517199706                                    Morning Ride ☀️     Ride
# 4  7507557354                          CycleBar - Afternoon Ride     Ride
#
#   sport_type start_date_local start_time  \
# 0       Ride       2022-07-30   12:29:34
# 1    Workout       2022-07-29   15:30:41
# 2       Ride       2022-07-26   18:00:54
# 3       Ride       2022-07-23   09:12:21
# 4       Ride       2022-07-21   16:27:51
#
#                                 start_latlng  \
# 0   [38.77374228090048, -121.36347443796694]
# 1                                         []
# 2  [38.773648738861084, -121.36368323117495]
# 3  [38.633550172671676, -121.21844915673137]
# 4                                         []
#
#                                  end_latlng  distance  moving_time  \
# 0  [38.77376575022936, -121.36364182457328]   27470.9         4602
# 1                                        []       0.0         1199
# 2  [38.77378385514021, -121.36365816928446]   18334.6         3094
# 3  [38.63322361372411, -121.21896212920547]   50871.7         9835
# 4                                        []       0.0         2923
#
#    elapsed_time  average_speed  max_speed  average_cadence  average_heartrate  \
# 0          5205          5.969      8.935             65.6              133.4
# 1          1199          0.000      0.000              NaN                NaN
# 2          3210          5.926      8.766             64.1              131.4
# 3         12885          5.173     12.998             62.5              139.9
# 4          2923          0.000      0.000              NaN              153.8
#
#    max_heartrate  suffer_score  total_elevation_gain  elev_high  elev_low  \
# 0          157.0          42.0                  73.0       37.6      15.2
# 1            NaN           NaN                   0.0        NaN       NaN
# 2          155.0          25.0                  38.0       36.4      21.0
# 3          169.0         146.0                 419.0      149.0      35.4
# 4          178.0          86.0                   0.0        NaN       NaN
#
#         map.id                               map.summary_polyline  \
# 0  a7555695408  kfukFvzzcVIlCRr@R|AFlBt@bEhDzJGtDC\c@lASvC?xAL...
# 1  a7550519896                                               None
# 2  a7534784479  mfukFz{zcVGvAFd@Lf@X~BCj@@Xv@fEv@~Bf@hA~@jCJh@...
# 3  a7517199706  urxjFhnzbVXWiAiG}D?Tc@fD`@^}Aw@}B}DkAS_IjBmCcF...
# 4  a7507557354                                               None
#
#    map.resource_state
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2
