# %% [markdown]
# # STRAVA API AND CYCLING ACTIVITY SUMMARY DATA
# ---
# ---

# %%
# https://towardsdatascience.com/using-the-strava-api-and-pandas-to-explore-your-activity-data-d94901d9bfde
# https://www.youtube.com/watch?v=sgscChKfGyg&t=258s
# https://github.com/franchyze923/Code_From_Tutorials/blob/master/Strava_Api/strava_api.py
# Lesson 5.01 APIs
# Lesson 8.02 Timeseries

# %% [markdown]
# # Imports
# ---

# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import requests
import urllib3

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# # API
# ---

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

payload = {
    'client_id': "89682",
    'client_secret': '0211f1fcd1e21bf52f9690ed169fcbd4d886f602',
    'refresh_token': '7a3f31cb96a242deb9e08de21eee388496d44bd0',
    'grant_type': "refresh_token",
    'f': 'json'
}

print("Requesting Token...\n")
res = requests.post(auth_url, data=payload, verify=False)
access_token = res.json()['access_token']
print("Access Token = {}\n".format(access_token))

header = {'Authorization': 'Bearer ' + access_token}
param = {'per_page': 200, 'page': 1}
my_dataset = requests.get(activites_url, headers=header, params=param).json()

print(my_dataset[0]["name"])
print(my_dataset[0]["map"]["summary_polyline"])
# Out:
# Requesting Token...
#
# Access Token = 6bea001c784cadc7ec582396cc539c0b52063aca
#
# Afternoon Ride ☀️
# gfukFrzzcVKhCT|@RtAFl@@fAb@vCT`AzCjIHh@GjBA~@k@lBQfD@x@P`Aa@f@}@rBmAfE{B`Bs@`AETAdAGReEnEYHcGuA{@Cm@c@wBEq@Y}AkAOAmAx@s@HoAf@uABaA]}@Te@@_AOk@TyBd@cBR]Co@WcDImAQ_Ak@mATw@M]]g@{@i@_@y@{@e@s@_CgESe@G]Ly@A[q@qAg@{C?c@P}CVoIAgGaEJwAE_AJgJMeD@GQBwIUWe@Wg@CoBq@]EMu@l@kB^w@d@i@lGyCtDiCbBgC`CkEFWTiEr@uFd@{BlBqFG]u@u@[m@CiFG}@P_Fd@wDDiC^cADYVsMVwFZ_B|A_G`AgBdCaEH[?_@o@iEQ_Co@}E}@aGWe@i@a@gC_Aw@iAs@o@aAuCiAoB_BaBkBoECcAT}JWcDH_BO{@Cg@@{BGu@[e@QKqAKWYkBkH_AqFk@gCGaAOQYGQOCm@HaC_@}IU{BaCwEQmBK_@eB}Es@gAWq@?w@T}A`A}AP}ADgA^u@f@Wt@E`@g@N_AFcAEi@_@cCu@mAa@SeAIeAc@}DO}@MsA@g@[Ss@g@}ECy@TiBv@oAJ_@PoABo@GkAAgCa@}@G]B_@n@wBKuCZqF@cBO{As@oEa@kAg@cAu@iDOsG[o@wCoE_@eAG]D_@NYtBoCn@cBFiFPk@LKx@QIGYVe@NKTIh@?pCKtA]fA_CbDSj@B`@J\b@`AnBrCx@|ADVDjFp@dDPf@n@pA`@pBn@dFCvAYbGJhCm@nBC`@Bp@Z^LtF[|BaAfBOfBb@bEZfB`@j@d@H~@E~F\x@`@|AT`@d@b@z@^zCS|BKVi@`@_@@o@Vi@v@Av@UfB_AdBUdB@f@FX|AdC`BdFRlBbC~EHh@\nHDrBKlDNRd@JPrAbAhEh@`Db@pBpArEbBT`@^Lb@?pDV`AKlBRvCQbIAfBDZnBtE|A`B|@zA~AtDn@f@r@dAzAf@~@h@`@x@zApKTpCr@nF?p@M\wDnGgB`HYdBIbBe@bQGd@c@vAEb@@bCTL`@A|@Oh@c@Xw@JGnGTpDIpDs@jAa@zBkApOkLb@a@nAcBz@yAPIVLtAxAlE~D~DbE|A|@

# %%
# JSON
activities = json_normalize(my_dataset)

# %%
activities.head()
# Out:
#    resource_state                                               name  \
# 0               2                                  Afternoon Ride ☀️
# 1               2                                      Lunch Ride ☀️
# 2               2  20 min EDM Full Body Strength with Daniel McKenna
# 3               2                                    Evening Ride ☀️
# 4               2                                    Morning Ride ☀️
#
#    distance  moving_time  elapsed_time  total_elevation_gain     type  \
# 0   23107.4         4091          4543                  38.0     Ride
# 1   27470.9         4602          5205                  73.0     Ride
# 2       0.0         1199          1199                   0.0  Workout
# 3   18334.6         3094          3210                  38.0     Ride
# 4   50871.7         9835         12885                 419.0     Ride
#
#   sport_type  workout_type          id            start_date  \
# 0       Ride           NaN  7567212212  2022-08-01T23:23:23Z
# 1       Ride           NaN  7555695408  2022-07-30T19:29:34Z
# 2    Workout           NaN  7550519896  2022-07-29T22:30:41Z
# 3       Ride           NaN  7534784479  2022-07-27T01:00:54Z
# 4       Ride          10.0  7517199706  2022-07-23T16:12:21Z
#
#        start_date_local                         timezone  utc_offset  \
# 0  2022-08-01T16:23:23Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 1  2022-07-30T12:29:34Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 2  2022-07-29T15:30:41Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 3  2022-07-26T18:00:54Z  (GMT-08:00) America/Los_Angeles    -25200.0
# 4  2022-07-23T09:12:21Z  (GMT-08:00) America/Los_Angeles    -25200.0
#
#   location_city location_state location_country  achievement_count  \
# 0          None           None    United States                  0
# 1          None           None    United States                  0
# 2          None           None    United States                  0
# 3          None           None    United States                  0
# 4          None           None    United States                 29
#
#    kudos_count  comment_count  athlete_count  photo_count  trainer  commute  \
# 0            0              0              1            0    False    False
# 1            0              0              1            0    False    False
# 2            1              0              1            0     True    False
# 3            1              0              1            0    False    False
# 4            1              0              1            0    False    False
#
#    manual  private visibility  flagged    gear_id  \
# 0   False    False   everyone    False  b10571102
# 1   False    False   everyone    False  b10571102
# 2   False    False   everyone    False       None
# 3   False    False   everyone    False  b10571102
# 4   False    False   everyone    False  b10571102
#
#                                 start_latlng  \
# 0  [38.774071438238025, -121.36280070059001]
# 1   [38.77374228090048, -121.36347443796694]
# 2                                         []
# 3  [38.773648738861084, -121.36368323117495]
# 4  [38.633550172671676, -121.21844915673137]
#
#                                  end_latlng  average_speed  max_speed  \
# 0    [38.773751584813, -121.36365129612386]          5.648      8.552
# 1  [38.77376575022936, -121.36364182457328]          5.969      8.935
# 2                                        []          0.000      0.000
# 3  [38.77378385514021, -121.36365816928446]          5.926      8.766
# 4  [38.63322361372411, -121.21896212920547]          5.173     12.998
#
#    average_cadence  has_heartrate  average_heartrate  max_heartrate  \
# 0             65.0           True              114.6          140.0
# 1             65.6           True              133.4          157.0
# 2              NaN          False                NaN            NaN
# 3             64.1           True              131.4          155.0
# 4             62.5           True              139.9          169.0
#
#    heartrate_opt_out  display_hide_heartrate_option  elev_high  elev_low  \
# 0              False                           True       28.2       8.6
# 1              False                           True       37.6      15.2
# 2              False                          False        NaN       NaN
# 3              False                           True       36.4      21.0
# 4              False                           True      149.0      35.4
#
#     upload_id upload_id_str                           external_id  \
# 0  8070502046    8070502046                garmin_push_9319516883
# 1  8057653527    8057653527                garmin_push_9305828885
# 2  8051901564    8051901564  30df8ed553b1444e9bc0b25090e29ef4.tcx
# 3  8034472252    8034472252                garmin_push_9281307583
# 4  8014855808    8014855808                garmin_push_9260725778
#
#    from_accepted_tag  pr_count  total_photo_count  has_kudoed  suffer_score  \
# 0              False         0                  0       False          14.0
# 1              False         0                  0       False          42.0
# 2              False         0                  1       False           NaN
# 3              False         0                  0       False          25.0
# 4              False        13                  1       False         146.0
#
#    athlete.id  athlete.resource_state       map.id  \
# 0     7321904                       1  a7567212212
# 1     7321904                       1  a7555695408
# 2     7321904                       1  a7550519896
# 3     7321904                       1  a7534784479
# 4     7321904                       1  a7517199706
#
#                                 map.summary_polyline  map.resource_state  \
# 0  gfukFrzzcVKhCT|@RtAFl@@fAb@vCT`AzCjIHh@GjBA~@k...                   2
# 1  kfukFvzzcVIlCRr@R|AFlBt@bEhDzJGtDC\c@lASvC?xAL...                   2
# 2                                               None                   2
# 3  mfukFz{zcVGvAFd@Lf@X~BCj@@Xv@fEv@~Bf@hA~@jCJh@...                   2
# 4  urxjFhnzbVXWiAiG}D?Tc@fD`@^}Aw@}B}DkAS_IjBmCcF...                   2
#
#    average_watts  max_watts  weighted_average_watts  kilojoules device_watts
# 0            NaN        NaN                     NaN         NaN          NaN
# 1            NaN        NaN                     NaN         NaN          NaN
# 2            NaN        NaN                     NaN         NaN          NaN
# 3            NaN        NaN                     NaN         NaN          NaN
# 4            NaN        NaN                     NaN         NaN          NaN

# %%
activities.columns
# Out:
# Index(['resource_state', 'name', 'distance', 'moving_time', 'elapsed_time',
#        'total_elevation_gain', 'type', 'sport_type', 'workout_type', 'id',
#        'start_date', 'start_date_local', 'timezone', 'utc_offset',
#        'location_city', 'location_state', 'location_country',
#        'achievement_count', 'kudos_count', 'comment_count', 'athlete_count',
#        'photo_count', 'trainer', 'commute', 'manual', 'private', 'visibility',
#        'flagged', 'gear_id', 'start_latlng', 'end_latlng', 'average_speed',
#        'max_speed', 'average_cadence', 'has_heartrate', 'average_heartrate',
#        'max_heartrate', 'heartrate_opt_out', 'display_hide_heartrate_option',
#        'elev_high', 'elev_low', 'upload_id', 'upload_id_str', 'external_id',
#        'from_accepted_tag', 'pr_count', 'total_photo_count', 'has_kudoed',
#        'suffer_score', 'athlete.id', 'athlete.resource_state', 'map.id',
#        'map.summary_polyline', 'map.resource_state', 'average_watts',
#        'max_watts', 'weighted_average_watts', 'kilojoules', 'device_watts'],
#       dtype='object')

# %%
#Break date into start time and date
activities['start_date_local'] = pd.to_datetime(activities['start_date_local'])
activities['start_time'] = activities['start_date_local'].dt.time
activities['start_date_local'] = activities['start_date_local'].dt.date

# %%
# clean up to wanted columns
cols = ['id', 'name', 'type', 'sport_type', 'start_date_local', 'start_time', 
        'start_latlng', 'end_latlng', 'distance', 'moving_time', 'elapsed_time', 
        'average_speed', 'max_speed', 'average_cadence', 'average_heartrate', 
        'max_heartrate', 'suffer_score', 'total_elevation_gain', 'elev_high', 
        'elev_low', 'map.id', 'map.summary_polyline', 'map.resource_state']
activities = activities[cols]

# %%
activities.head()
# Out:
#            id                                               name     type  \
# 0  7567212212                                  Afternoon Ride ☀️     Ride
# 1  7555695408                                      Lunch Ride ☀️     Ride
# 2  7550519896  20 min EDM Full Body Strength with Daniel McKenna  Workout
# 3  7534784479                                    Evening Ride ☀️     Ride
# 4  7517199706                                    Morning Ride ☀️     Ride
#
#   sport_type start_date_local start_time  \
# 0       Ride       2022-08-01   16:23:23
# 1       Ride       2022-07-30   12:29:34
# 2    Workout       2022-07-29   15:30:41
# 3       Ride       2022-07-26   18:00:54
# 4       Ride       2022-07-23   09:12:21
#
#                                 start_latlng  \
# 0  [38.774071438238025, -121.36280070059001]
# 1   [38.77374228090048, -121.36347443796694]
# 2                                         []
# 3  [38.773648738861084, -121.36368323117495]
# 4  [38.633550172671676, -121.21844915673137]
#
#                                  end_latlng  distance  moving_time  \
# 0    [38.773751584813, -121.36365129612386]   23107.4         4091
# 1  [38.77376575022936, -121.36364182457328]   27470.9         4602
# 2                                        []       0.0         1199
# 3  [38.77378385514021, -121.36365816928446]   18334.6         3094
# 4  [38.63322361372411, -121.21896212920547]   50871.7         9835
#
#    elapsed_time  average_speed  max_speed  average_cadence  average_heartrate  \
# 0          4543          5.648      8.552             65.0              114.6
# 1          5205          5.969      8.935             65.6              133.4
# 2          1199          0.000      0.000              NaN                NaN
# 3          3210          5.926      8.766             64.1              131.4
# 4         12885          5.173     12.998             62.5              139.9
#
#    max_heartrate  suffer_score  total_elevation_gain  elev_high  elev_low  \
# 0          140.0          14.0                  38.0       28.2       8.6
# 1          157.0          42.0                  73.0       37.6      15.2
# 2            NaN           NaN                   0.0        NaN       NaN
# 3          155.0          25.0                  38.0       36.4      21.0
# 4          169.0         146.0                 419.0      149.0      35.4
#
#         map.id                               map.summary_polyline  \
# 0  a7567212212  gfukFrzzcVKhCT|@RtAFl@@fAb@vCT`AzCjIHh@GjBA~@k...
# 1  a7555695408  kfukFvzzcVIlCRr@R|AFlBt@bEhDzJGtDC\c@lASvC?xAL...
# 2  a7550519896                                               None
# 3  a7534784479  mfukFz{zcVGvAFd@Lf@X~BCj@@Xv@fEv@~Bf@hA~@jCJh@...
# 4  a7517199706  urxjFhnzbVXWiAiG}D?Tc@fD`@^}Aw@}B}DkAS_IjBmCcF...
#
#    map.resource_state
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2
