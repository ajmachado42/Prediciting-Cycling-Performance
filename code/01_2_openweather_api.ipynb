# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import requests
import urllib3

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
url_current = "https://api.openweathermap.org/data/3.0/onecall?lat=38.752125&lon=-121.288010&exclude=current,minutely,daily&appid=2f01a2c2a7f1ffcb24807b893d1ba1d2"
req = requests.get(url_current)
print(req.status_code)
w_current = req.json()
# Out:
# 200

# %%
w_current.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'hourly'])

# %%
w_current_df = json_normalize(w_current['hourly'])

# %%
w_current_df
# Out:
#             dt    temp  feels_like  pressure  humidity  dew_point   uvi  \
# 0   1659639600  308.22      307.33      1009        27     286.43  8.48
# 1   1659643200  308.21      307.91      1009        30     288.04  9.23
# 2   1659646800  308.83      308.16      1009        27     286.95  8.74
# 3   1659650400  309.73      308.58      1008        23     285.25  7.16
# 4   1659654000  310.75      309.51      1008        21     284.71  4.95
# 5   1659657600  311.11      309.35      1007        18     282.70  2.74
# 6   1659661200  309.27      307.20      1007        18     281.37  1.15
# 7   1659664800  306.21      304.22      1007        21     281.19  0.31
# 8   1659668400  302.76      301.31      1009        26     281.30  0.00
# 9   1659672000  300.32      299.68      1009        30     281.34  0.00
# 10  1659675600  298.81      298.29      1010        33     281.28  0.00
# 11  1659679200  297.80      297.23      1010        35     281.21  0.00
# ...
